# %%
import yfinance as yf 

#Q1    Use yfinance to Extract Stock Data
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

tesla_data_reset_index = tesla_data.reset_index()
print(tesla_data_reset_index.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0
# /home/name/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
#Q2  Use Webscraping to Extract Tesla Revenue Data
print(tesla_data_reset_index.tail())
# Out:
#                           Date        Open        High         Low  \
# 3525 2024-07-02 00:00:00-04:00  218.889999  231.300003  218.059998
# 3526 2024-07-03 00:00:00-04:00  234.559998  248.350006  234.250000
# 3527 2024-07-05 00:00:00-04:00  249.809998  252.369995  242.460007
# 3528 2024-07-08 00:00:00-04:00  247.710007  259.440002  244.570007
# 3529 2024-07-09 00:00:00-04:00  251.000000  257.860596  250.300003
#
#            Close     Volume  Dividends  Stock Splits
# 3525  231.259995  205047900        0.0           0.0
# 3526  246.389999  166561500        0.0           0.0
# 3527  251.520004  154501200        0.0           0.0
# 3528  252.940002  156918900        0.0           0.0
# 3529  257.429993   28522493        0.0           0.0

# %%
#3 Use yfinance to Extract Stock Data
gme = yf.Ticker("GME")
gme_data = tesla.history(period="max")

gme_data_reset_index = gme_data.reset_index()
print(gme_data_reset_index.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0
# /home/name/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
#4  Use Webscraping to Extract GME Revenue Data
print(gme_data_reset_index.tail())
# Out:
#                           Date        Open        High         Low  \
# 3525 2024-07-02 00:00:00-04:00  218.889999  231.300003  218.059998
# 3526 2024-07-03 00:00:00-04:00  234.559998  248.350006  234.250000
# 3527 2024-07-05 00:00:00-04:00  249.809998  252.369995  242.460007
# 3528 2024-07-08 00:00:00-04:00  247.710007  259.440002  244.570007
# 3529 2024-07-09 00:00:00-04:00  251.000000  258.200012  250.300003
#
#            Close     Volume  Dividends  Stock Splits
# 3525  231.259995  205047900        0.0           0.0
# 3526  246.389999  166561500        0.0           0.0
# 3527  251.520004  154501200        0.0           0.0
# 3528  252.940002  156918900        0.0           0.0
# 3529  258.100006   30232492        0.0           0.0

# %%
#5Plot Tesla Stock Graph
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Close Price')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()


tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

make_graph(tesla_data, "Tesla Stock Price")
# Out:
# /home/name/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
#6 Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph.

tesla = yf.Ticker("GME")
tesla_data = tesla.history(period="max")

make_graph(tesla_data, "GameStop Stock Price")
# Out:
# /home/name/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
